# %% [markdown]
# - sample have 1000 obersvation from a population will check the distribution(it's normal distribution)
# - will take 1000 sample(having some observations) check the distribution
# - will calculate all 1000 sample means
# - then will form a distribution of 1000 sample means
# - finally will test with 30 sample mean distribution

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px

# %%
s=np.random.randint(1,10,1000)
s
# Out:
# array([8, 5, 8, 7, 5, 9, 8, 3, 4, 9, 2, 8, 1, 6, 9, 4, 1, 5, 2, 7, 2, 8,
#        9, 7, 9, 7, 2, 6, 1, 3, 5, 2, 4, 3, 7, 3, 5, 2, 4, 6, 5, 4, 5, 1,
#        5, 9, 1, 9, 5, 7, 4, 1, 1, 6, 1, 8, 1, 2, 2, 6, 8, 8, 2, 4, 2, 5,
#        3, 9, 6, 1, 1, 5, 5, 9, 5, 1, 3, 5, 7, 3, 3, 9, 4, 4, 7, 5, 1, 2,
#        8, 9, 3, 9, 2, 2, 1, 9, 1, 9, 1, 4, 8, 8, 7, 5, 4, 7, 7, 2, 4, 6,
#        6, 9, 9, 2, 2, 1, 7, 4, 4, 8, 2, 7, 9, 2, 5, 2, 3, 9, 5, 8, 1, 7,
#        7, 7, 8, 1, 1, 7, 5, 7, 7, 7, 4, 6, 9, 8, 6, 5, 1, 6, 3, 8, 9, 1,
#        1, 1, 5, 5, 3, 2, 9, 2, 6, 3, 4, 3, 7, 6, 5, 7, 5, 5, 3, 5, 8, 5,
#        5, 6, 9, 8, 8, 3, 6, 3, 3, 7, 1, 6, 7, 4, 7, 4, 3, 5, 5, 7, 5, 6,
#        7, 6, 6, 4, 3, 3, 4, 5, 4, 9, 5, 4, 9, 9, 2, 3, 2, 5, 5, 4, 1, 1,
#        4, 9, 3, 2, 9, 8, 4, 3, 9, 6, 2, 6, 5, 6, 5, 4, 6, 1, 2, 6, 4, 4,
#        4, 8, 2, 5, 9, 5, 1, 4, 5, 4, 2, 6, 4, 1, 3, 9, 4, 8, 1, 1, 9, 1,
#        8, 5, 3, 9, 3, 5, 3, 7, 8, 9, 5, 6, 4, 1, 6, 4, 9, 4, 1, 2, 6, 4,
# ...

# %%
plt.hist(s)
# Out:
# (array([128.,  99., 105., 120.,   0., 134., 109.,  97., 108., 100.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(s)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
px.histogram(s)
# Out:
# <div>                            <div id="c470d956-81fc-4675-808e-f38d97509449" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c470d956-81fc-4675-808e-f38d97509449")) {                    Plotly.newPlot(                        "c470d956-81fc-4675-808e-f38d97509449",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[8,5,8,7,5,9,8,3,4,9,2,8,1,6,9,4,1,5,2,7,2,8,9,7,9,7,2,6,1,3,5,2,4,3,7,3,5,2,4,6,5,4,5,1,5,9,1,9,5,7,4,1,1,6,1,8,1,2,2,6,8,8,2,4,2,5,3,9,6,1,1,5,5,9,5,1,3,5,7,3,3,9,4,4,7,5,1,2,8,9,3,9,2,2,1,9,1,9,1,4,8,8,7,5,4,7,7,2
# ...

# %% [markdown]
# # population not follows normal distribution

# %%
s=np.random.randint(1,1000,100000)
# in our population values are from 1 to 1000
# population size is 1lakh

# %%
a1=np.random.randint(1,8,2)
a1
# Out:
# array([2, 1])

# %%
a2=np.random.randint(1,8,3)
a2
# Out:
# array([7, 1, 7])

# %%
for i in range(2,1000):
    a=np.random.randint(1,8,i)
    print(a)
# Out:
# [3 6]
# [4 3 5]
# [6 4 6 7]
# [1 3 6 4 1]
# [1 1 1 7 3 1]
# [1 2 2 5 6 2 7]
# [5 7 1 1 1 7 2 3]
# [3 4 3 7 4 4 7 2 3]
# [7 4 1 2 5 2 1 5 1 4]
# [1 2 2 7 1 3 7 6 4 1 3]
# [6 1 5 1 5 1 5 5 4 6 2 5]
# [3 2 6 4 5 7 3 2 7 7 7 5 5]
# [7 7 4 5 3 3 6 3 4 4 6 2 7 3]
# [4 7 5 5 2 6 4 1 1 2 4 3 1 2 7]
# [4 3 5 7 6 2 3 7 5 5 1 1 3 7 7 1]
# [3 3 1 7 1 5 2 1 7 7 1 2 2 6 7 1 7]
# [6 5 5 1 4 5 1 7 7 6 3 3 6 6 1 5 7 2]
# [3 5 4 7 5 1 6 1 6 4 5 1 7 6 2 7 7 7 5]
# [5 6 2 7 6 2 2 6 4 7 1 2 2 4 2 3 7 1 7 4]
# [5 1 3 3 7 5 4 3 1 4 7 5 1 2 7 4 4 5 6 3 6]
# [1 7 2 4 4 3 3 7 5 5 3 4 6 4 3 2 1 7 6 7 6 4]
# [2 2 6 4 2 4 6 6 4 2 4 3 6 4 3 1 5 5 5 2 2 3 4]
# [7 7 1 5 4 4 1 1 7 1 3 6 6 6 1 5 5 5 6 2 7 7 4 7]
# [1 5 5 4 5 2 5 5 6 5 2 2 2 4 3 6 6 2 1 5 7 7 5 6 6]
# [3 5 5 4 3 7 4 7 3 3 6 3 3 7 6 6 3 4 3 2 2 4 3 2 4 5]
# [3 3 4 1 6 6 2 3 5 6 2 5 7 3 4 4 6 7 3 5 6 4 6 2 6 4 4]
# [1 4 1 2 3 5 5 4 4 7 1 1 2 4 5 7 3 1 1 6 6 2 5 6 6 3 7 3]
# [4 5 2 3 2 6 1 5 1 6 5 5 7 1 7 1 7 6 1 5 6 2 3 7 2 7 4 3 7]
# ...

# %%
means=[]
for i in range(1,1000):
    s=np.random.randint(1,8,i)
    means.append(np.mean(s))

# %%
means
# each sample mean appendend into means list
# Out:
# [6.0,
#  3.5,
#  1.3333333333333333,
#  3.25,
#  3.8,
#  5.333333333333333,
#  4.142857142857143,
#  3.5,
#  2.888888888888889,
#  3.4,
#  3.727272727272727,
#  4.083333333333333,
#  4.3076923076923075,
#  4.5,
#  3.933333333333333,
#  3.9375,
#  3.6470588235294117,
#  4.277777777777778,
#  3.789473684210526,
#  4.25,
#  4.523809523809524,
#  3.8181818181818183,
#  3.652173913043478,
#  4.75,
#  4.08,
#  4.0,
#  4.111111111111111,
#  4.214285714285714,
#  4.137931034482759,
#  3.7,
#  4.0,
#  4.34375,
#  4.151515151515151,
#  4.117647058823529,
#  3.8857142857142857,
#  4.111111111111111,
#  4.837837837837838,
#  3.3157894736842106,
#  4.153846153846154,
#  3.95,
#  4.585365853658536,
#  4.119047619047619,
#  3.883720930232558,
#  4.2727272727272725,
#  3.8666666666666667,
#  3.9347826086956523,
#  4.361702127659575,
#  4.083333333333333,
#  3.7142857142857144,
#  3.82,
#  4.176470588235294,
#  4.0576923076923075,
#  3.830188679245283,
#  3.7962962962962963,
#  4.527272727272727,
# ...

# %%
means[0:5]
# Out:
# [6.0, 3.5, 1.3333333333333333, 3.25, 3.8]

# %%
plt.hist(means[0:5])
plt.show()

# %%
sns.histplot(means[0:5])
plt.show()

# %%
px.histogram(means[0:5])
# Out:
# <div>                            <div id="a72292d0-5992-43f4-81b3-cc46b9879abe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a72292d0-5992-43f4-81b3-cc46b9879abe")) {                    Plotly.newPlot(                        "a72292d0-5992-43f4-81b3-cc46b9879abe",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[6.0,3.5,1.3333333333333333,3.25,3.8],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"c
# ...

# %%
sns.histplot(means[0:20])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(means[0:100])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(means[0:200],kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.distplot(means[0:300])
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:ylabel='Density'>

# %%
px.histogram(means[0:300],marginal="violin") # box # rug (give a straight line )
# Out:
# <div>                            <div id="b8b08150-fecd-4fb3-b022-9679b8551502" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8b08150-fecd-4fb3-b022-9679b8551502")) {                    Plotly.newPlot(                        "b8b08150-fecd-4fb3-b022-9679b8551502",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[5.0,5.5,4.0,5.25,4.4,4.166666666666667,4.428571428571429,2.625,4.444444444444445,3.3,2.909090909090909,4.583333333333333,3.076923076923077,4.5,4.4,3.5,3.588235294117647,4.055555555555555,3.789473684210526,4.0,4.3333
# ...

# %%
means=[]
for i in range(1,1000):
    np.random.seed(1)  # give same values in every run 
    s=np.random.randint(1,8,10) 
    means.append(np.mean(s))

# %%
px.distplot(means[0:300])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 px.distplot(means[0:300])
#
# AttributeError: module 'plotly.express' has no attribute 'distplot'
