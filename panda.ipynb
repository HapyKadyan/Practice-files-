# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - pandas is very important
# - 80% work data  analysis:
# - python pandas --------- pyspark
#
# - after learning pandas ---------- learn pyspark
# - dealing with dataframes data
# - how to read text files and json files
# - suppose you have csv files excel files ----> pandas
# - uploaded csv files MSSQL ------> analysis

# %%
bank_data=pd.read_csv('D:\\data\\bank.csv',sep=';')
# reading a file

# %%
bank_data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ## creating a data frame using list

# %%
names=['ram','anil','happy','singh','ram']
d1=pd.DataFrame(names)
d1
# Out:
#        0
# 0    ram
# 1   anil
# 2  happy
# 3  singh
# 4    ram

# %%
names=['ram','anil','happy','singh','ram']
d1=pd.DataFrame(names,columns=["names"])
d1
# Out:
#    names
# 0    ram
# 1   anil
# 2  happy
# 3  singh
# 4    ram

# %%
names=['ram','anil','happy','singh','ram']
ages=[10,20,30,40,50]
d2=pd.DataFrame(zip(names,ages),columns=["names",'ages'])
d2
# Out:
#    names  ages
# 0    ram    10
# 1   anil    20
# 2  happy    30
# 3  singh    40
# 4    ram    50

# %%
# case-2
list1=[["ram",30],['laxman',35],['anil',40],['krishna',45]]
d3=pd.DataFrame(list1,columns=['names','ages'])
d3
# Out:
#      names  ages
# 0      ram    30
# 1   laxman    35
# 2     anil    40
# 3  krishna    45

# %% [markdown]
# ## creating data frame by using dictionary

# %%
dict1={"names":['ram','anil','happy','singh','ram'],
      'ages':[10,20,30,40,50],
      'city':["hyd","pune",'goa','delhi',"chennai"]}
d2=pd.DataFrame(dict1,columns=["names",'ages',"city"])
d2
# Out:
#    names  ages     city
# 0    ram    10      hyd
# 1   anil    20     pune
# 2  happy    30      goa
# 3  singh    40    delhi
# 4    ram    50  chennai

# %%
bank_data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_data.head()
# top 5 rows
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank_data.head(2)
# first 2 rows
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   30  unemployed  married    primary      no     1787      no   no
# 1   33    services  married  secondary      no     4789     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no

# %%
bank_data.head(10)
# top 10 rows
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   30     unemployed  married    primary      no     1787      no   no
# 1   33       services  married  secondary      no     4789     yes  yes
# 2   35     management   single   tertiary      no     1350     yes   no
# 3   30     management  married   tertiary      no     1476     yes  yes
# 4   59    blue-collar  married  secondary      no        0     yes   no
# 5   35     management   single   tertiary      no      747      no   no
# 6   36  self-employed  married   tertiary      no      307     yes   no
# 7   39     technician  married  secondary      no      147     yes   no
# 8   41   entrepreneur  married   tertiary      no      221     yes   no
# 9   43       services  married    primary      no      -88     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# ...

# %%
bank_data.tail()
# last 5 rows
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
bank_data.tail(2)
# last two rows
# Out:
#       age           job  marital  education default  balance housing loan  \
# 4519   28   blue-collar  married  secondary      no     1137      no   no
# 4520   44  entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
bank_data.tail(10)
# last 10 rows
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4511   46    blue-collar  married  secondary      no      668     yes   no
# 4512   40    blue-collar  married  secondary      no     1100     yes   no
# 4513   49    blue-collar  married  secondary      no      322      no   no
# 4514   38    blue-collar  married  secondary      no     1205     yes   no
# 4515   32       services   single  secondary      no      473     yes   no
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
bank_data.tail(100)
# last 100 rows
# Out:
#       age            job   marital  education default  balance housing loan  \
# 4421   30     management    single   tertiary      no     7845     yes   no
# 4422   37       services  divorced    primary      no      260     yes   no
# 4423   45     management    single   tertiary      no     2048     yes   no
# 4424   34     management   married   tertiary      no     1557     yes  yes
# 4425   35       services   married  secondary      no      505     yes  yes
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4516   33       services   married  secondary      no     -333     yes   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
# 4518   57     technician   married  secondary      no      295      no   no
# 4519   28    blue-collar   married  secondary      no     1137      no   no
# 4520   44   entrepreneur    single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_data.shape()
# gives shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 bank_data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
bank_data.shape
# don't use ()
# in shape or size
# Out:
# (4521, 17)

# %%
bank_data.size
# 4521*17
# Out:
# 76857

# %%
bank_data.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
b=bank_data.columns
# don't use ()

# %%
data1=bank_data.dtypes
data1
# data type of each column
# object means it is string type
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
data1={k:v for k,v in zip(b,a)}

# %%
data1
# Out:
# {'age': dtype('int64'),
#  'job': dtype('O'),
#  'marital': dtype('O'),
#  'education': dtype('O'),
#  'default': dtype('O'),
#  'balance': dtype('int64'),
#  'housing': dtype('O'),
#  'loan': dtype('O'),
#  'contact': dtype('O'),
#  'day': dtype('int64'),
#  'month': dtype('O'),
#  'duration': dtype('int64'),
#  'campaign': dtype('int64'),
#  'pdays': dtype('int64'),
#  'previous': dtype('int64'),
#  'poutcome': dtype('O'),
#  'y': dtype('O')}

# %%
data1.keys()
# Out:
# dict_keys(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'y'])

# %%
data1.values()
# Out:
# dict_values([dtype('int64'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('int64'), dtype('O'), dtype('O'), dtype('O'), dtype('int64'), dtype('O'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('O'), dtype('O')])

# %%
data1.fromkeys("int64")
# Out:
# {'i': None, 'n': None, 't': None, '6': None, '4': None}

# %%
a={v:k for k,v in zip(data1.values(),data1.keys())}
a
# Out:
# {'age': dtype('int64'),
#  'job': dtype('O'),
#  'marital': dtype('O'),
#  'education': dtype('O'),
#  'default': dtype('O'),
#  'balance': dtype('int64'),
#  'housing': dtype('O'),
#  'loan': dtype('O'),
#  'contact': dtype('O'),
#  'day': dtype('int64'),
#  'month': dtype('O'),
#  'duration': dtype('int64'),
#  'campaign': dtype('int64'),
#  'pdays': dtype('int64'),
#  'previous': dtype('int64'),
#  'poutcome': dtype('O'),
#  'y': dtype('O')}

# %%
new={k:v for k,v in zip (a.keys(),a.values() )}
new
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 new={k:v for k,v in zip (a.keys(),a.values() )}
#       2 new
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
data1
# Out:
# {'age': dtype('int64'),
#  'job': dtype('O'),
#  'marital': dtype('O'),
#  'education': dtype('O'),
#  'default': dtype('O'),
#  'balance': dtype('int64'),
#  'housing': dtype('O'),
#  'loan': dtype('O'),
#  'contact': dtype('O'),
#  'day': dtype('int64'),
#  'month': dtype('O'),
#  'duration': dtype('int64'),
#  'campaign': dtype('int64'),
#  'pdays': dtype('int64'),
#  'previous': dtype('int64'),
#  'poutcome': dtype('O'),
#  'y': dtype('O')}

# %%
num_list=[]
obj_list=[]
for i in data1:
    if data1.values()== "int64":
        num_list.append(i)

# %%
num_list=[k for k,v in data1.items() if v == 'int64']
ob_list=[k for k,v in data1.items() if v=="O"]

# %%
num_list=[k for k,v in data1.items() if v in ["int64","int32","float64","float32"]]
ob_list=[k for k,v in data1.items() if v=="O"]

# %%
ob_list
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome',
#  'y']

# %%
data1
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
list1={v:{k} for k,v in data1.items if v.keys[k]=="int64"}
list2={k:v for k,v in data1.items() if v=="O"}
#list3=dict(list1,list2)
list1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 list1={v:{k} for k,v in data1.items if v.keys[k]=="int64"}
#       2 list2={k:v for k,v in data1.items() if v=="O"}
#       3 #list3=dict(list1,list2)
#
# TypeError: 'method' object is not iterable

# %%
Data=dict(bank_data.dtypes)
list_obj=[]
list_int=[]
for i in Data:
    if Data[i]=='int64':
        list_int.append(i)
    else:
        list_obj.append(i)

# %%
bank_data.info()
# 4521 rows
# 0 to 4520
# 17 column
# 4521 entries having values (4521 non-null ) (here no values are missed)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %% [markdown]
# **Accessing your data**

# %% [markdown]
# - .iloc() ..... retrive the rows and columns by position
# - .loc() ...... retrives the elements columns by names

# %% [markdown]
# **iloc()**

# %%
# i want only first 5 columns 
# first 4 rows 
# [rows,column]
bank_data.iloc[0:5,0:6] # indexing start from zero
# iloc() works on indexing 
# bank_data.iloc[1,:3] not equals to [1][:3]
# bcz [1] means 1 index rows [:3] means rows start from zero and stop at 2 
# there no coulmns are defined 
# if we want to give colmn name then seperate rows and column by []
# bank_data.iloc[1]["age"] # [1,"age"] not works # [1,["age"]] also not work
# [1]["age"] 1 index where "age"
# .iloc means indexing loc
# Out:
#    age          job  marital  education default  balance
# 0   30   unemployed  married    primary      no     1787
# 1   33     services  married  secondary      no     4789
# 2   35   management   single   tertiary      no     1350
# 3   30   management  married   tertiary      no     1476
# 4   59  blue-collar  married  secondary      no        0

# %%
bank_data.iloc[-1:-10,0:5] # we can't get output
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default]
# Index: []

# %%
bank_data.iloc[-1,0:3]
# only last row information
# Out:
# age                  44
# job        entrepreneur
# marital          single
# Name: 4520, dtype: object

# %%
bank_data.iloc[1]
# only second row information having index 1
# we can skip columns
# can we skip rows
# Out:
# age                 33
# job           services
# marital        married
# education    secondary
# default             no
# balance           4789
# housing            yes
# loan               yes
# contact       cellular
# day                 11
# month              may
# duration           220
# campaign             1
# pdays              339
# previous             4
# poutcome       failure
# y                   no
# Name: 1, dtype: object

# %%
bank_data.iloc[0]
# first row information
# Out:
# age                  30
# job          unemployed
# marital         married
# education       primary
# default              no
# balance            1787
# housing              no
# loan                 no
# contact        cellular
# day                  19
# month               oct
# duration             79
# campaign              1
# pdays                -1
# previous              0
# poutcome        unknown
# y                    no
# Name: 0, dtype: object

# %%
bank_data.iloc[,0:4]
# we have to provide rows
# Out:
#   Input In [102]
#     bank_data.iloc[,0:4]
#                    ^
# SyntaxError: invalid syntax

# %%
bank_data.iloc[-2,0:5]
# Out:
# age                   28
# job          blue-collar
# marital          married
# education      secondary
# default               no
# Name: 4519, dtype: object

# %%
bank_data.iloc[-10:-1,0:6]
# Out:
#       age            job  marital  education default  balance
# 4511   46    blue-collar  married  secondary      no      668
# 4512   40    blue-collar  married  secondary      no     1100
# 4513   49    blue-collar  married  secondary      no      322
# 4514   38    blue-collar  married  secondary      no     1205
# 4515   32       services   single  secondary      no      473
# 4516   33       services  married  secondary      no     -333
# 4517   57  self-employed  married   tertiary     yes    -3313
# 4518   57     technician  married  secondary      no      295
# 4519   28    blue-collar  married  secondary      no     1137

# %%
bank_data.iloc[-10:,-8:]
# Out:
#       day month  duration  campaign  pdays  previous poutcome    y
# 4511   15   may      1263         2     -1         0  unknown  yes
# 4512   29   may       660         2     -1         0  unknown   no
# 4513   14   aug       356         2     -1         0  unknown   no
# 4514   20   apr        45         4    153         1  failure   no
# 4515    7   jul       624         5     -1         0  unknown   no
# 4516   30   jul       329         5     -1         0  unknown   no
# 4517    9   may       153         1     -1         0  unknown   no
# 4518   19   aug       151        11     -1         0  unknown   no
# 4519    6   feb       129         4    211         3    other   no
# 4520    3   apr       345         2    249         7    other   no

# %%
bank_data.iloc[100]
# 100 rows information
# Out:
# age                   36
# job          blue-collar
# marital          married
# education      secondary
# default               no
# balance                0
# housing              yes
# loan                  no
# contact          unknown
# day                    6
# month                may
# duration             337
# campaign               1
# pdays                 -1
# previous               0
# poutcome         unknown
# y                     no
# Name: 100, dtype: object

# %%
bank_data.iloc[100,200,300] 
# in oreder to get 100 ,200,300 index rows put one more list in it
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [105], in <cell line: 1>()
# ----> 1 bank_data.iloc[100,200,300]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1458, in _iLocIndexer._getitem_tuple(self, tup)
#    1456 def _getitem_tuple(self, tup: tuple):
# -> 1458     tup = self._validate_tuple_indexer(tup)
#    1459     with suppress(IndexingError):
#    1460         return self._getitem_lowerdim(tup)
#
# ...

# %%
bank_data.iloc[[100,200,300]]
# 101 row having index 100
# Out:
#      age          job   marital  education default  balance housing loan  \
# 100   36  blue-collar   married  secondary      no        0     yes   no
# 200   34   technician    single   tertiary      no      992     yes   no
# 300   70      retired  divorced    primary      no     4531      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome   y
# 100   unknown    6   may       337         1     -1         0  unknown  no
# 200  cellular    4   may       301         1     88         2  success  no
# 300  cellular   18   may       445         1     -1         0  unknown  no

# %%
bank_data.iloc[[100,200,300],:3]
# Out:
#      age          job   marital
# 100   36  blue-collar   married
# 200   34   technician    single
# 300   70      retired  divorced

# %%
bank_data.iloc[1,"age"] 
# seperate rows and columns by []
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:769, in _LocationIndexer._validate_tuple_indexer(self, key)
#     768 try:
# --> 769     self._validate_key(k, i)
#     770 except ValueError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1378, in _iLocIndexer._validate_key(self, key, axis)
#    1377 else:
# -> 1378     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [110], in <cell line: 1>()
# ----> 1 bank_data.iloc[1,"age"]
#
# ...

# %%
bank_data.iloc[1]["age"]
# Out:
# 33

# %%
bank_data.iloc[1][:]
# Out:
# age                 33
# job           services
# marital        married
# education    secondary
# default             no
# balance           4789
# housing            yes
# loan               yes
# contact       cellular
# day                 11
# month              may
# duration           220
# campaign             1
# pdays              339
# previous             4
# poutcome       failure
# y                   no
# Name: 1, dtype: object

# %%
bank_data.iloc[0:5][1:5]
# [0:5] # where columns are mentioned 
# [1:5]
# Out:
#    age          job  marital  education default  balance housing loan  \
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank_data.iloc[0:5,1:3][1:5]
# Out:
#            job  marital
# 1     services  married
# 2   management   single
# 3   management  married
# 4  blue-collar  married

# %%
bank_data.iloc[0:5,1:3][1:5,2:4]
# error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(1, 5, None), slice(2, 4, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [120], in <cell line: 1>()
# ----> 1 bank_data.iloc[0:5,1:3][1:5,2:4]
#
# ...

# %%
bank_data.iloc[1:9]["job"]
# Out:
# 1         services
# 2       management
# 3       management
# 4      blue-collar
# 5       management
# 6    self-employed
# 7       technician
# 8     entrepreneur
# Name: job, dtype: object

# %%
bank_data.iloc["job"]
# iloc not gives values 
# in iloc we can't get values using names 
# get values only indexing or [1:3]["job"] where job #
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [122], in <cell line: 1>()
# ----> 1 bank_data.iloc["job"]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1517, in _iLocIndexer._getitem_axis(self, key, axis)
#    1515 key = item_from_zerodim(key)
#    1516 if not is_integer(key):
# -> 1517     raise TypeError("Cannot index by location index with a non-integer key")
#    1519 # validate the location
#    1520 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
bank_data.iloc[[100,200,300],0:5]
# but here i only need age and education column only 
# but iloc provide column value in order start from this to this
# Out:
#      age          job   marital  education default
# 100   36  blue-collar   married  secondary      no
# 200   34   technician    single   tertiary      no
# 300   70      retired  divorced    primary      no

# %%
# in the same way i can't get a specific column values
# from above i want to get only job,loan,month coumns value only 
# but in iloc we can't do that 
# that's why we need loc()

# %%
bank_data.iloc[1:9,0:7:2]
# but how can we get only specific columns value
# Out:
#    age  marital default housing
# 1   33  married      no     yes
# 2   35   single      no     yes
# 3   30  married      no     yes
# 4   59  married      no     yes
# 5   35   single      no      no
# 6   36  married      no     yes
# 7   39  married      no     yes
# 8   41  married      no     yes

# %%
bank_data.iloc[[100,200,400],[1,4,6]]
# i get but using indexing 
# suppose big data is there 
# and there are one lakh coumns then counting index of that column is default
# that's why we need .loc()
# Out:
#              job default housing
# 100  blue-collar      no     yes
# 200   technician      no     yes
# 400   technician      no     yes

# %%
bank_data.iloc[:,[1,4,8]]
# Out:
#                 job default   contact
# 0        unemployed      no  cellular
# 1          services      no  cellular
# 2        management      no  cellular
# 3        management      no   unknown
# 4       blue-collar      no   unknown
# ...             ...     ...       ...
# 4516       services      no  cellular
# 4517  self-employed     yes   unknown
# 4518     technician      no  cellular
# 4519    blue-collar      no  cellular
# 4520   entrepreneur      no  cellular
#
# [4521 rows x 3 columns]

# %%
bank_data.loc[0:5,["age","job","contact"]]
# Out:
#    age          job   contact
# 0   30   unemployed  cellular
# 1   33     services  cellular
# 2   35   management  cellular
# 3   30   management   unknown
# 4   59  blue-collar   unknown
# 5   35   management  cellular

# %%
bank_data.iloc[1:4,["age"]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [136], in <cell line: 1>()
# ----> 1 bank_data.iloc[1:4,["age"]]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1458, in _iLocIndexer._getitem_tuple(self, tup)
#    1456 def _getitem_tuple(self, tup: tuple):
# -> 1458     tup = self._validate_tuple_indexer(tup)
#    1459     with suppress(IndexingError):
#    1460         return self._getitem_lowerdim(tup)
#
# ...

# %%
bank_data.loc[1,["age"]]
# in .iloc not works
# Out:
# age    33
# Name: 1, dtype: object

# %%
bank_data.loc[1:9,["age","job"]]
# we can access data using columns name in .loc
# Out:
#    age            job
# 1   33       services
# 2   35     management
# 3   30     management
# 4   59    blue-collar
# 5   35     management
# 6   36  self-employed
# 7   39     technician
# 8   41   entrepreneur
# 9   43       services

# %%
bank_data.loc[5:23,["loan","default","marital"]]
# Out:
#    loan default   marital
# 5    no      no    single
# 6    no      no   married
# 7    no      no   married
# 8    no      no   married
# 9   yes      no   married
# 10   no      no   married
# 11   no      no   married
# 12   no      no   married
# 13   no      no    single
# 14  yes      no   married
# 15  yes      no   married
# 16   no      no   married
# 17   no      no    single
# 18   no      no    single
# 19   no      no   married
# 20   no      no  divorced
# 21   no      no  divorced
# 22   no      no    single
# 23   no      no   married

# %% [markdown]
# **reading columnn**

# %%
bank_data.columns
# reading all column
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
bank_data["age"] 
# read a column
# Out:
# 0       30
# 1       33
# 2       35
# 3       30
# 4       59
#         ..
# 4516    33
# 4517    57
# 4518    57
# 4519    28
# 4520    44
# Name: age, Length: 4521, dtype: int64

# %%
min1=(min(bank_data["age"]))
min1
# Out:
# 19

# %%
min1=bank_data["age"].min() # both are correct 
min1
# Out:
# 19

# %%
max1=(max(bank_data["age"]))
max1
# Out:
# 87

# %%
max1=bank_data["age"].max()
max1
# Out:
# 87

# %%
bank_data["age"].unique()
# only unique values will come
# Out:
# array([30, 33, 35, 59, 36, 39, 41, 43, 20, 31, 40, 56, 37, 25, 38, 42, 44,
#        26, 55, 67, 53, 68, 32, 49, 78, 23, 52, 34, 61, 45, 48, 57, 54, 63,
#        51, 29, 50, 27, 60, 28, 21, 58, 22, 46, 24, 77, 75, 47, 70, 65, 64,
#        62, 66, 19, 81, 83, 80, 71, 72, 69, 79, 73, 86, 74, 76, 87, 84],
#       dtype=int64)

# %%
uni=bank_data["age"].nunique()
uni
# number of unique values
# Out:
# 67

# %%
len1=len(bank_data["age"])
len1
# count
# Out:
# 4521

# %%
# min     max      nunique     count
# 19      87       67           4521

# now task is create a data frame from above these values
# dataframe can be created by list or dict

# %%
#len1=list(len(bank_data["age"]))

# %%
#uni=list(bank_data["age"].nunique())

# %%
#data1=pd.DataFrame(zip(min1,max1,len1,uni))

# %%
# m1
data=pd.DataFrame({"min":min1,"max":max1,"unique":uni,"len":len1})
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 # m1
# ----> 2 data=pd.DataFrame({"min":min1,"max":max1,"unique":uni,"len":len1})
#       3 data
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# ...

# %%
data=pd.DataFrame({"min":min1,"max":max1,"unique":uni,"len":len1},index=["age"]) # index can be anything 
data
# Out:
#      min  max  unique   len
# age   19   87      67  4521

# %%
data=pd.DataFrame({"min":min1,"max":max1,"unique":uni,"len":len1},index=["aaa"]) # index can be anything 
data     # here index is aaa
# Out:
#      min  max  unique   len
# aaa   19   87      67  4521

# %%
# or we can write above code as

# %%
data=pd.DataFrame({"min":bank_data["age"].min(),
                   "max":bank_data["age"].max(),
                   "unique":bank_data["age"].nunique(),
                   "len":len(bank_data["age"])},index=["age"]) # index can be anything 
data
# Out:
#      min  max  unique   len
# age   19   87      67  4521

# %%
data=pd.DataFrame({"min":[bank_data["age"].min()], # here we provide values in []
                   "max":[bank_data["age"].max()], # []
                   "unique":[bank_data["age"].nunique()], # we have to provide in scaler values or direct values
                   "len":[len(bank_data["age"])]}) # so no need to provide index 
data
# Out:
#    min  max  unique   len
# 0   19   87      67  4521

# %%
# m2
dict1={} # creating a empty dictionary
dict1["min"]=bank_data["age"].min() # adding new key value pair in dict1
dict1["max"]=bank_data["age"].max()
dict1["nunique"]=bank_data["age"].nunique()
dict1["len"]=len(bank_data["age"])
dict1
# Out:
# {'min': 19, 'max': 87, 'nunique': 67, 'len': 4521}

# %%
data1=pd.DataFrame(dict1,index=["age"]) # we have to give index
data1
# Out:
#      min  max  nunique   len
# age   19   87       67  4521

# %%
bank_data.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank_data["balance","housing","loan"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('balance', 'housing', 'loan')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
bank_data[["balance","housing","loan"]] 
# reading multiple columns
# Out:
#       balance housing loan
# 0        1787      no   no
# 1        4789     yes  yes
# 2        1350     yes   no
# 3        1476     yes  yes
# 4           0     yes   no
# ...       ...     ...  ...
# 4516     -333     yes   no
# 4517    -3313     yes  yes
# 4518      295      no   no
# 4519     1137      no   no
# 4520     1136     yes  yes
#
# [4521 rows x 3 columns]

# %%
bank_data["balance"]
# Out:
# 0       1787
# 1       4789
# 2       1350
# 3       1476
# 4          0
#         ...
# 4516    -333
# 4517   -3313
# 4518     295
# 4519    1137
# 4520    1136
# Name: balance, Length: 4521, dtype: int64

# %%
bank_data
# i want to know the count age group
# between 45 to 60
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_data["age"]>45
# ask question to system
# bool values
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4516    False
# 4517     True
# 4518     True
# 4519    False
# 4520    False
# Name: age, Length: 4521, dtype: bool

# %%
# if i want to get true values data 
bank_data[bank_data["age"]>45]
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4      59    blue-collar  married  secondary      no        0     yes   no
# 16     56     technician  married  secondary      no     4073      no   no
# 26     55    blue-collar  married    primary      no      627     yes   no
# 27     67        retired  married    unknown      no      696      no   no
# 28     56  self-employed  married  secondary      no      784      no  yes
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4509   51     technician  married   tertiary      no     2506      no   no
# 4511   46    blue-collar  married  secondary      no      668     yes   no
# 4513   49    blue-collar  married  secondary      no      322      no   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
#
# ...

# %%
len(bank_data[bank_data["age"]>45])
# there are 1481 guys whose age>45
# Out:
# 1481

# %%
# we can't use and or in pandas use & | 
(bank_data["age"]>=45) & (bank_data["age"]<60) # & work as and operator
# here we are asking
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4516    False
# 4517     True
# 4518     True
# 4519    False
# 4520    False
# Name: age, Length: 4521, dtype: bool

# %%
(bank_data["age"]>=45) | (bank_data["age"]<60) # | work as or operator
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 4516    True
# 4517    True
# 4518    True
# 4519    True
# 4520    True
# Name: age, Length: 4521, dtype: bool

# %%
a1=(bank_data["age"]>45) & (bank_data["age"]<60)
bank_data[a1]
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4      59    blue-collar  married  secondary      no        0     yes   no
# 16     56     technician  married  secondary      no     4073      no   no
# 26     55    blue-collar  married    primary      no      627     yes   no
# 28     56  self-employed  married  secondary      no      784      no  yes
# 29     53         admin.  married  secondary      no      105      no  yes
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4509   51     technician  married   tertiary      no     2506      no   no
# 4511   46    blue-collar  married  secondary      no      668     yes   no
# 4513   49    blue-collar  married  secondary      no      322      no   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
#
# ...

# %%
len(bank_data[a1])
# there are 1307 persons have age b/w 45 to 60
# Out:
# 1307

# %%
list1=[1,2,3,4,5,6,7]
for i in list1:
    if i>4 and i<7:
        print(i)
# Out:
# 5
# 6

# %%
for i in list1:
    print(i>4 | i<7)
# Out:
# False
# False
# False
# False
# False
# False
# False

# %%
a=10
b=8
print(a&b)
print(a|b)
# Out:
# 8
# 10

# %%
age_details=pd.DataFrame(dict1,index=["age"]) # we have to give index
age_details
# Out:
#      min  max  nunique   len
# age   19   87       67  4521

# %%
age_details.to_csv("age_details.csv")
# python file or csv file are in same location
# file saved

# %%
age_details.to_csv("D:\\data\\age_details.csv")
# python file or csv file are in different location 
# reading or saving a file same proceduce

# %%
a=bank_data["job"].value_counts()

# %%
data1=dict(a)

# %%
pd.DataFrame(data1,index=["count"]) # we have to give index
# Out:
#        management  blue-collar  technician  admin.  services  retired  \
# count         969          946         768     478       417      230
#
#        self-employed  entrepreneur  unemployed  housemaid  student  unknown
# count            183           168         128        112       84       38

# %%
dict1=dict(D)
Data1=pd.DataFrame(dict1,index=['count'])
Data1
# Out:
#        management  blue-collar  technician  admin.  services  retired  \
# count         969          946         768     478       417      230
#
#        self-employed  entrepreneur  unemployed  housemaid  student  unknown
# count            183           168         128        112       84       38

# %%
job_type=bank_data["y"].value_counts()
job_type
# Out:
# no     4000
# yes     521
# Name: y, dtype: int64
