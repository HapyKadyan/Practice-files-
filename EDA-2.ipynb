# %% [markdown]
# - EDA(explorartort data analysis)
# - stastics
# - mean-median-mode ......... done
# - standard deviation-variance......done
# - Emperical rule ( theortical part )
# - chebyshive inequality (theortical part)
# - bargraphs()
# - histograms ........done
# - pie chart
# - correlation ............ done
# - heat map ............ done
# - normal distribution ........ done
# - skew analysis
# - outliers analysis (done)--------- seperate python
# - boxplot()
# - missing values analysis (done)

# %% [markdown]
# - histogram
# - distribution plot
# - correlation plot
# - scatterplot

# %% [markdown]
# - for prevailing wage we have seen skewd distribution

# %% [markdown]
# **Box plot**
#
# $prevailing$$wage$

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
visa_data_set=pd.read_csv("D:\\data\\visadataset.csv")
visa_data_set
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# using matplotlib
plt.boxplot(visa_data_set["prevailing_wage"])
plt.show()

# %%
# find outliers ???
# first calculate Q1,Q2 and IQR

# %%
Q1=round(np.percentile(visa_data_set["prevailing_wage"],25),2)
Q3=round(np.percentile(visa_data_set["prevailing_wage"],75),2)
print(Q1)
print(Q3)
IQR=Q3-Q1
print(IQR)
l_b=Q1-1.5*IQR
u_b=Q3+1.5*IQR
print("lower outliers ",l_b)
print("upper outliers",u_b)
# Out:
# 34015.48
# 107735.51
# 73720.03
# lower outliers  -76564.565
# upper outliers 218315.555

# %%
# using seaborn
sns.boxplot(visa_data_set["prevailing_wage"])
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='prevailing_wage'>

# %%
sns.boxplot(data=visa_data_set["prevailing_wage"])
# Out:
# <AxesSubplot:>

# %%
visa_data_set[visa_data_set["continent"]=="Asia"]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
plt.show()

# %%
# find outliers of every specific column
# find median 
# print median on boxplot
# print Q1,Q2,Q3,values on boxplot

# %%
Q1=np.percentile(visa_data_set["prevailing_wage"],25)
Q1 # all data Q1 but we want to calculate for a specific column
# Out:
# 34015.479999999996

# %%
visa_data_set[visa_data_set["continent"]=="Asia"]["prevailing_wage"]
# first we select only asia then in asia prevailing wage values
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 5         78252.1400
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 16861, dtype: float64

# %%
asia=visa_data_set[visa_data_set["continent"]=="Asia"]["prevailing_wage"]
Q1=np.percentile(asia,25)
Q2=np.percentile(asia,50)
Q3=np.percentile(asia,75)
IOR=Q3-Q1
print("Q1",Q1)
print("median",Q2)
print("Q3",Q3)
print("lower outlier ",Q1-IQR*1.5)
print("upper outlier ",Q3+1.5*IQR)
# Out:
# Q1 40573.13
# median 76168.88
# Q3 112538.43
# lower outlier  -70006.91500000001
# upper outlier  223118.47499999998

# %%
# put all these thing on asia boxplot

# %%
visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# groupy contient values then median of prevailing wage
# Out:
# continent
# Africa           75126.310
# Asia             76168.880
# Europe           52073.335
# North America    64289.875
# Oceania          68656.045
# South America    53511.705
# Name: prevailing_wage, dtype: float64

# %%
visa_data_set.groupby(["continent"]).first()
# first value of every continent group
# Out:
#                case_id education_of_employee has_job_experience  \
# continent
# Africa          EZYV05              Master's                  Y
# Asia            EZYV01           High School                  N
# Europe          EZYV10             Doctorate                  Y
# North America   EZYV08            Bachelor's                  Y
# Oceania        EZYV242             Doctorate                  Y
# South America  EZYV122            Bachelor's                  N
#
#               requires_job_training  no_of_employees  yr_of_estab  \
# continent
# Africa                            N             1082         2005
# Asia                              N            14513         2007
# Europe                            N             2251         1995
# North America                     N             3035         1924
# Oceania                           N             2871         2009
# South America                     N             1415         1913
#
# ...

# %%
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
box_plot
# Out:
# <AxesSubplot:xlabel='continent', ylabel='prevailing_wage'>

# %%
box_plot.get_xticks()
# it will give number of box plot starting from zero
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
medians[0]
# Out:
# 75126.31

# %%
medians[2]
# Out:
# 52073.335

# %%
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i, # selecting box 
                  medians[i], # value
                  medians[i]) # position on the boxplot 
 # here values are not placed as we want

# %%
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i+1, # selecting box 
                  medians[i], # value
                  medians[i]) # position on the boxplot where value placed

# %%
for i in box_plot.get_xticks():
    print(i,medians[i])
# Out:
# 0 75126.31
# 1 76168.88
# 2 52073.335
# 3 64289.875
# 4 68656.045
# 5 53511.705

# %%
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i,medians[i],medians[i],horizontalalignment="center")
    # here values are in center but some values are out of the boxplot

# %%
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i,medians[i],medians[i],horizontalalignment="center",size="small")
    # but i want to increase the fig size how??

# %%
plt.figure(figsize=(10,6))
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i,medians[i],medians[i],horizontalalignment="center",size="small")

# %%
plt.figure(figsize=(10,3)) # here first value is horizontal size and second is vertical 
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i,medians[i],medians[i],horizontalalignment="center",size="small")

# %%
plt.figure(figsize=(4,8)) # here first value is horizontal size and second is vertical 
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i,medians[i],medians[i],horizontalalignment="center",size="small")

# %%
# we can also change the color of median text how??

# %%
plt.figure(figsize=(10,3)) # here first value is horizontal size and second is vertical 
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i,medians[i],medians[i],horizontalalignment="center",size="small",color="w")

# %%
# we can also bold the values or add background color

# %%
plt.figure(figsize=(10,3)) # here first value is horizontal size and second is vertical 
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i,medians[i],medians[i],
                  horizontalalignment="center",
                  size="small",
                  color="w",
                  weight='semibold',
                  backgroundcolor="r") # adding background color

# %%
plt.figure(figsize=(10,3)) # here first value is horizontal size and second is vertical 
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i,medians[i],medians[i],
                  horizontalalignment="center",
                  size="small",
                  color="w",
                  weight='semibold',
                  backgroundcolor="r") # adding background color 
    # shift + tab to show all methods

# %%
# we can also change the style of grid

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,3)) # here first value is horizontal size and second is vertical 
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i,medians[i],medians[i],
                  horizontalalignment="center",
                  size="small",
                  color="w",
                  weight='semibold',
                  backgroundcolor="r") # adding background color 
    # shift + tab to show all methods

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(10,3)) # here first value is horizontal size and second is vertical 
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i,medians[i],medians[i],
                  horizontalalignment="center",
                  size="small",
                  color="w",
                  weight='semibold',
                  backgroundcolor="r") # adding background color 
    # shift + tab to show all methods

# %%
sns.set_style("dark")
plt.figure(figsize=(10,3)) # here first value is horizontal size and second is vertical 
box_plot=sns.boxplot(x="continent",y="prevailing_wage",data=visa_data_set)
medians=visa_data_set.groupby(["continent"])["prevailing_wage"].median()
# box_plot.get_xticsk() 
for i in box_plot.get_xticks():
    box_plot.text(i,medians[i],medians[i],
                  horizontalalignment="center",
                  size="small",
                  color="w",
                  weight='semibold',
                  backgroundcolor="r") # adding background color 
    # shift + tab to show all methods

# %%
visa_data_set["continent"].value_counts()
# count how many asia values are there in the visa data set
# Out:
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: continent, dtype: int64

# %%
# one coulmn is continent 
# other column is count 
# create a dataframe
continent        count 
Asia             16861
Europe            3732
North America     3292
South America      852
Africa             551
Oceania            192
# Out:
#   Input In [84]
#     continent        count
#                      ^
# SyntaxError: invalid syntax

# %%
# M-1
dict1=dict(visa_data_set["continent"].value_counts())
pd.DataFrame(dict1,index=np.arange(6))
# here 6 indexs so 6 values
# Out:
#     Asia  Europe  North America  South America  Africa  Oceania
# 0  16861    3732           3292            852     551      192
# 1  16861    3732           3292            852     551      192
# 2  16861    3732           3292            852     551      192
# 3  16861    3732           3292            852     551      192
# 4  16861    3732           3292            852     551      192
# 5  16861    3732           3292            852     551      192

# %%
# M-2
count_data=visa_data_set["continent"].value_counts()
dict1=dict(count_data)
pd.DataFrame(dict1,index=["count"]) 
# here one index
# Out:
#         Asia  Europe  North America  South America  Africa  Oceania
# count  16861    3732           3292            852     551      192

# %%
count_data=visa_data_set["continent"].value_counts()
dict1=dict(count_data)
pd.DataFrame(dict1,index=["count"]).T
# but where is the continent column name
# Out:
#                count
# Asia           16861
# Europe          3732
# North America   3292
# South America    852
# Africa           551
# Oceania          192

# %%
# M-3
list1=dict(count_data)
list2=[key for key in list1.keys()]
list2
# Out:
# ['Asia', 'Europe', 'North America', 'South America', 'Africa', 'Oceania']

# %%
list1=dict(count_data)
list2=[key for key in list1.keys()]
list3=[value for value in list1.values()]
pd.DataFrame(zip(list2,list3))
# Out:
#                0      1
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
list1=dict(count_data)
list2=[key for key in list1.keys()]
list3=[value for value in list1.values()]
cc=pd.DataFrame(zip(list2,list3),columns=["continent","count"])
cc
# Out:
#        continent  count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %% [markdown]
# # bar plot

# %%
sns.barplot(x="continent",y="count",data=cc)
# Out:
# <AxesSubplot:xlabel='continent', ylabel='count'>

# %%
# using matplotlib

# %%
plt.bar("continent","count",data=cc)
plt.show()

# %%
# see the differnce bw snsbarplot and pltbar

# %%
plt.bar(x="continent",height="count",data=cc)
plt.show()

# %% [markdown]
# # count plot

# %%
sns.countplot(y="continent",data=visa_data_set)
# Out:
# <AxesSubplot:xlabel='count', ylabel='continent'>

# %%
sns.countplot(x="continent",data=visa_data_set)
# Out:
# <AxesSubplot:xlabel='continent', ylabel='count'>

# %%
# count plot directly calculate values

# %%
sns.countplot(x="continent",data=visa_data_set,
             order=visa_data_set["continent"].value_counts().index)
# Out:
# <AxesSubplot:xlabel='continent', ylabel='count'>

# %%
sns.countplot(x="continent",data=visa_data_set,
             order=["Asia","Europe","North America","South America","Africa","Oceania"])
# Out:
# <AxesSubplot:xlabel='continent', ylabel='count'>

# %%
sns.countplot(x="continent",data=visa_data_set,
             order=["Asia","Europe","North America","South America","Africa","Oceania","Asia","Europe"])
# Out:
# <AxesSubplot:xlabel='continent', ylabel='count'>

# %%
sns.countplot(x="continent",data=visa_data_set,
             order=["Europe","North America","South America"])
# Out:
# <AxesSubplot:xlabel='continent', ylabel='count'>

# %% [markdown]
# **Observation**

# %% [markdown]
# - in our visa data set most of the observation belongs to asia
# - second highest value is Europe
# - third highest value is North america

# %%
# order=["Asia","Europe","North America","South America","Africa","Oceania","Asia","Europe"])
# order=visa_data_set["continent"].value_counts().index
# both are same

# %%
visa_data_set["continent"].value_counts()
# Out:
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: continent, dtype: int64

# %%
visa_data_set["continent"].value_counts().index
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object')

# %%
# apply count plot on education of the employes

# %%
visa_data_set.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
sns.countplot(visa_data_set["education_of_employee"])
plt.show()
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# count the values of education of employee
visa_data_set["education_of_employee"].value_counts()
# Out:
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: education_of_employee, dtype: int64

# %%
visa_data_set["education_of_employee"].value_counts().index
# Out:
# Index(['Bachelor's', 'Master's', 'High School', 'Doctorate'], dtype='object')

# %%
# most of the observation lies in bachelor's then master

# %%
sns.countplot(data=visa_data_set,x="education_of_employee",
              order=visa_data_set["education_of_employee"].value_counts().index)
# now this is in decreasing order
# Out:
# <AxesSubplot:xlabel='education_of_employee', ylabel='count'>

# %%
# now compare education of employee in continent wise

# %%
sns.countplot(data=visa_data_set,x="education_of_employee",hue="continent")
# Out:
# <AxesSubplot:xlabel='education_of_employee', ylabel='count'>

# %%
sns.countplot(data=visa_data_set,hue="education_of_employee",x="continent")
# Out:
# <AxesSubplot:xlabel='continent', ylabel='count'>

# %%
sns.countplot(data=visa_data_set,x="education_of_employee",hue="continent",
             order=visa_data_set["continent"].value_counts().index)
# Out:
# <AxesSubplot:xlabel='education_of_employee', ylabel='count'>

# %%
sns.countplot(data=visa_data_set,x="education_of_employee",hue="continent",
             order=visa_data_set["education_of_employee"].value_counts().index)
# we have to the give the order of x
# Out:
# <AxesSubplot:xlabel='education_of_employee', ylabel='count'>

# %%
# now count how many bachelor's are there have job experience 
sns.countplot(data=visa_data_set,x="education_of_employee",hue="has_job_experience")
# Out:
# <AxesSubplot:xlabel='education_of_employee', ylabel='count'>

# %%
sns.countplot(data=visa_data_set,x="education_of_employee",hue="has_job_experience",
             order="Bachelor's")
# Out:
# <AxesSubplot:xlabel='education_of_employee', ylabel='count'>

# %%
sns.countplot(data=visa_data_set,hue="education_of_employee",x="has_job_experience",
             order="Y")
# Out:
# <AxesSubplot:xlabel='has_job_experience', ylabel='count'>

# %%
# count how many bachelors are there has job experience

# %%
visa_data_set[(visa_data_set["education_of_employee"]=="Bachelor's") | (visa_data_set["has_job_experience"]=='Y')]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
sns.countplot(data=visa_data_set,x="education_of_employee",hue="has_job_experience")
# Out:
# <AxesSubplot:xlabel='education_of_employee', ylabel='count'>

# %%
len(visa_data_set[(visa_data_set["education_of_employee"]=="Bachelor's")&\
                  (visa_data_set["has_job_experience"]=='Y')])
# Out:
# 5886

# %%
# here 5886 are bachelor's has job experince

# %%
# above we can do this in pandas using crosstab

# %%
pd.crosstab(visa_data_set["education_of_employee"],visa_data_set["has_job_experience"])
# Out:
# has_job_experience        N     Y
# education_of_employee
# Bachelor's             4348  5886
# Doctorate               941  1251
# High School            1396  2024
# Master's               3993  5641

# %%
r1=pd.crosstab(visa_data_set["has_job_experience"],visa_data_set["education_of_employee"])
r1
# Out:
# education_of_employee  Bachelor's  Doctorate  High School  Master's
# has_job_experience
# N                            4348        941         1396      3993
# Y                            5886       1251         2024      5641

# %%
r1.plot(kind="bar")
# we draw bar plot with r1 
# kind things must be in string
# Out:
# <AxesSubplot:xlabel='has_job_experience'>

# %%
r2=pd.crosstab(visa_data_set["education_of_employee"],visa_data_set["has_job_experience"])
r2.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='education_of_employee'>

# %%
r2.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
r1.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
r1.plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
r2.plot(kind="density")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
r1.plot(kind="hexbin") # data frame only 
# it require x and y
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [197], in <cell line: 1>()
# ----> 1 r1.plot(kind="hexbin")
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:917, in PlotAccessor.__call__(self, *args, **kwargs)
#     915 if kind in self._dataframe_kinds:
#     916     if isinstance(data, ABCDataFrame):
# --> 917         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918     else:
#     919         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:70, in plot(data, kind, **kwargs)
#      68             ax = plt.gca()
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      71 plot_obj.generate()
#      72 plot_obj.draw()
#
# ...

# %%
# continent
# education_of_employee
# has_job_experience

# we have seen individual count plot
# we have seen with hue
# we get the values pd.crosstab 
# based on the cross tab we visualize

# will apply cross tab on three features

# %%
x=visa_data_set["continent"]
y=visa_data_set["education_of_employee"]
z=visa_data_set["has_job_experience"]
pd.crosstab(x,y,z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [203], in <cell line: 4>()
#       2 y=visa_data_set["education_of_employee"]
#       3 z=visa_data_set["has_job_experience"]
# ----> 4 pd.crosstab(x,y,z)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:632, in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     629     raise ValueError("aggfunc cannot be used without values.")
#     631 if values is not None and aggfunc is None:
# --> 632     raise ValueError("values cannot be used without an aggfunc.")
#     634 if not is_nested_list_like(index):
#     635     index = [index]
#
# ValueError: values cannot be used without an aggfunc.

# %%
x=visa_data_set["continent"]
y=visa_data_set["education_of_employee"]
z=visa_data_set["has_job_experience"]
pd.crosstab([x,y],z)
# Out:
# has_job_experience                      N     Y
# continent     education_of_employee
# Africa        Bachelor's               64    79
#               Doctorate                22    32
#               High School              25    41
#               Master's                106   182
# Asia          Bachelor's             3033  4135
#               Doctorate               404   519
#               High School             928  1362
#               Master's               2706  3774
# Europe        Bachelor's              538   761
#               Doctorate               358   488
#               High School             207   283
#               Master's                473   624
# North America Bachelor's              527   698
#               Doctorate               101   157
#               High School             165   236
#               Master's                555   853
# Oceania       Bachelor's               32    34
#               Doctorate                12    10
# ...

# %%
x=visa_data_set["continent"]
y=visa_data_set["education_of_employee"]
z=visa_data_set["has_job_experience"]
pd.crosstab([x,z],y)
# Out:
# education_of_employee             Bachelor's  Doctorate  High School  Master's
# continent     has_job_experience
# Africa        N                           64         22           25       106
#               Y                           79         32           41       182
# Asia          N                         3033        404          928      2706
#               Y                         4135        519         1362      3774
# Europe        N                          538        358          207       473
#               Y                          761        488          283       624
# North America N                          527        101          165       555
#               Y                          698        157          236       853
# Oceania       N                           32         12           14        31
#               Y                           34         10           22        37
# ...

# %%
x=visa_data_set["continent"]
y=visa_data_set["education_of_employee"]
z=visa_data_set["has_job_experience"]
pd.crosstab([z,y],x)
# Out:
# continent                                 Africa  Asia  Europe  North America  \
# has_job_experience education_of_employee
# N                  Bachelor's                 64  3033     538            527
#                    Doctorate                  22   404     358            101
#                    High School                25   928     207            165
#                    Master's                  106  2706     473            555
# Y                  Bachelor's                 79  4135     761            698
#                    Doctorate                  32   519     488            157
#                    High School                41  1362     283            236
#                    Master's                  182  3774     624            853
#
# continent                                 Oceania  South America
# has_job_experience education_of_employee
# N                  Bachelor's                  32            154
# ...

# %%
r3=pd.crosstab([x,z],y)
# plt.figure(figsize=(10,200)) not working bcz we working on plt 
r3.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='continent,has_job_experience'>

# %%
visa_data_set["education_of_employee"].value_counts()
# Out:
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: education_of_employee, dtype: int64

# %%
visa_data_set.shape
# Out:
# (25480, 12)

# %%
10234/25480 = 40%
# the same thing we get using normalization
# Out:
# 0.40164835164835166

# %%
visa_data_set["education_of_employee"].value_counts(normalize=True)
# here are 78% persons have min. education is graduation
# Out:
# Bachelor's     0.401648
# Master's       0.378100
# High School    0.134223
# Doctorate      0.086028
# Name: education_of_employee, dtype: float64

# %%
visa_data_set.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
sns.countplot(visa_data_set["requires_job_training"])
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='requires_job_training', ylabel='count'>

# %%
visa_data_set["requires_job_training"].value_counts()
# Out:
# N    22525
# Y     2955
# Name: requires_job_training, dtype: int64

# %%
visa_data_set["requires_job_training"].value_counts(normalize=True)
# Out:
# N    0.884027
# Y    0.115973
# Name: requires_job_training, dtype: float64

# %%
# there are 88% persons how don't reqiure job training

# %% [markdown]
# <b> observation <b/> - almost 88% don't require job training

# %%
# <b> observation <b/> bold all the character

# %% [markdown]
# - as of now we have performed analysis on numerical column i.e. prevailing_wage
# - we have plot histogram,kde,boxplot
# - next we perfromed analysis on categorical column i.e. continent, has_job_experience,edication ... etc
# - we have plot bar plot, count plot, with hue, cross tab etc..
# - we have plot heat map i.e. correlation
# - we drawn scatterplots

# %%
visa_data_set[visa_data_set["education_of_employee"]=="Bachelor's"]["prevailing_wage"].mean()
# Out:
# 73405.44373546989

# %%
visa_data_set[visa_data_set["education_of_employee"]=="Bachelor's"].describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     10234.000000  10234.000000     10234.000000
# mean       5166.243893   1979.947332     73405.443735
# std       20789.221100     41.863658     52083.793080
# min         -26.000000   1800.000000         5.186800
# 25%        1002.000000   1976.250000     33545.362500
# 50%        2065.000000   1997.000000     69825.710000
# 75%        3394.750000   2005.000000    106453.335000
# max      594472.000000   2016.000000    314156.060000

# %%
# count plot needs single categorical value
# bar plot need one numerical and one cateogorical value
# bar plot prevailing wage vs education of employee

# %%
sns.barplot(data=visa_data_set,x="prevailing_wage",y="education_of_employee")
# Out:
# <AxesSubplot:xlabel='prevailing_wage', ylabel='education_of_employee'>

# %%
sns.barplot(data=visa_data_set,y="prevailing_wage",x="education_of_employee")
# Out:
# <AxesSubplot:xlabel='education_of_employee', ylabel='prevailing_wage'>

# %%
# it will give the mean value of the prevailing wage based on the employee education 
# bachelor's mean value is 73405.44373546989
# the black line are error lines,means mean value have some intervals
# mean value might be slightly less than or greater than up down

# %%
sns.barplot(data=visa_data_set,y="prevailing_wage",x="has_job_experience")
# alomost same prevailing wage who has job experienced or not
# Out:
# <AxesSubplot:xlabel='has_job_experience', ylabel='prevailing_wage'>

# %%
visa_data_set["case_status"]
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %% [markdown]
# **case status**

# %%
visa_data_set["case_status"].value_counts()
# Out:
# Certified    17018
# Denied        8462
# Name: case_status, dtype: int64

# %%
visa_data_set["case_status"].value_counts(normalize=True)
# 66% get certified 
# now it is your task what's main reason people get certified or deined
# Out:
# Certified    0.667896
# Denied       0.332104
# Name: case_status, dtype: float64

# %%
sns.countplot(data=visa_data_set,x="case_status")
# Out:
# <AxesSubplot:xlabel='case_status', ylabel='count'>

# %%
plt.bar(visa_data_set["case_status"])
# this is the difference between count plot and bar plot 
# count plot draw the plot by counting it's own values 
# bar plot draw the values based on other numerical column
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [248], in <cell line: 1>()
# ----> 1 plt.bar(visa_data_set["case_status"])
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
plt.bar(visa_data_set["case_status"],visa_data_set["prevailing_wage"])
# Out:
# <BarContainer object of 25480 artists>

# %%
visa_data_set["case_status"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object>

# %%
visa_data_set["case_status"].value_counts()
# Out:
# Certified    17018
# Denied        8462
# Name: case_status, dtype: int64

# %%
values=visa_data_set["case_status"].value_counts().to_list()
values
# Out:
# [17018, 8462]

# %%
visa_data_set["case_status"].value_counts().index
# Out:
# Index(['Certified', 'Denied'], dtype='object')

# %%
labels=visa_data_set["case_status"].value_counts().index.to_list()
labels
# Out:
# ['Certified', 'Denied']

# %%
plt.pie(x=values,y=labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [261], in <cell line: 1>()
# ----> 1 plt.pie(x=values,y=labels)
#
# TypeError: pie() got an unexpected keyword argument 'y'

# %%
plt.pie(x=values,labels=labels)
# if we want to give values
# Out:
# ([<matplotlib.patches.Wedge at 0x25cdae94850>,
# ...
#  [Text(-0.553676164167787, 0.9504960311502862, 'Certified'),
#   Text(0.5536761641677869, -0.9504960311502864, 'Denied')])

# %%
plt.pie(x=values,labels=labels,
       autopct=("%1.2f%%"))
# Out:
# ([<matplotlib.patches.Wedge at 0x25cdaf34eb0>,
# ...
#  [Text(-0.553676164167787, 0.9504960311502862, 'Certified'),
#   Text(0.5536761641677869, -0.9504960311502864, 'Denied')],
#  [Text(-0.3020051804551565, 0.5184523806274288, '66.79%'),
#   Text(0.3020051804551564, -0.5184523806274289, '33.21%')])

# %%
# in seaborn to display in heat map we use annot=True
# in pie chart we use autopct to display values

# %%
plt.pie(x=values,labels=labels,
       autopct=("%1.2f%%"),
       edgecolor="r")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [270], in <cell line: 1>()
# ----> 1 plt.pie(x=values,labels=labels,
#       2        autopct=("%1.2f%%"),
#       3        edgecolor="r")
#
# TypeError: pie() got an unexpected keyword argument 'edgecolor'

# %%
wedgeprops

# %%
plt.pie(x=values,labels=labels,
       autopct=("%1.2f%%"),
        wedgeprops={"edgecolor":"red"})
# Out:
# ([<matplotlib.patches.Wedge at 0x25cdaf07dc0>,
# ...
#  [Text(-0.553676164167787, 0.9504960311502862, 'Certified'),
#   Text(0.5536761641677869, -0.9504960311502864, 'Denied')],
#  [Text(-0.3020051804551565, 0.5184523806274288, '66.79%'),
#   Text(0.3020051804551564, -0.5184523806274289, '33.21%')])

# %%
plt.pie(x=values,labels=labels,
       autopct=("%1.2f%%"),
        wedgeprops={"edgecolor":"red"},
       shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x25cdaa49970>,
# ...
#  [Text(-0.553676164167787, 0.9504960311502862, 'Certified'),
#   Text(0.5536761641677869, -0.9504960311502864, 'Denied')],
#  [Text(-0.3020051804551565, 0.5184523806274288, '66.79%'),
#   Text(0.3020051804551564, -0.5184523806274289, '33.21%')])

# %%
plt.pie(x=values,labels=labels,
       autopct=("%1.2f%%"),# 1.2 two values after decimal 
        wedgeprops={"edgecolor":"red"}, # dict 
       shadow=True,
       explode=[0.3,0.1]) # list # first value left side distance and second value is right side distance
# Out:
# ([<matplotlib.patches.Wedge at 0x25cdb0ae370>,
# ...
#  [Text(-0.7046787543953652, 1.2097222214640007, 'Certified'),
#   Text(0.6040103609103129, -1.0369047612548579, 'Denied')],
#  [Text(-0.4530077706827348, 0.7776785709411432, '66.79%'),
#   Text(0.3523393771976825, -0.6048611107320004, '33.21%')])

# %%
plt.pie(x=values,labels=labels,
       autopct=("%1.2f%%"),
        wedgeprops={"edgecolor":"red"}, # dict 
       shadow=True,
       explode=[0.1,0]) # list
# Out:
# ([<matplotlib.patches.Wedge at 0x25cdc1200a0>,
# ...
#  [Text(-0.604010360910313, 1.0369047612548576, 'Certified'),
#   Text(0.5536761641677869, -0.9504960311502864, 'Denied')],
#  [Text(-0.3523393771976826, 0.6048611107320003, '66.79%'),
#   Text(0.3020051804551564, -0.5184523806274289, '33.21%')])

# %%
plt.pie(x=values,labels=labels,
       autopct=("%1.2f%%"),
        wedgeprops={"edgecolor":"red"}, # dict 
       shadow=True,
       explode=[0.3,0.1],
       startangle=90) # list
# Out:
# ([<matplotlib.patches.Wedge at 0x25cdc166850>,
# ...
#  [Text(-1.2097222214640009, -0.7046787543953651, 'Certified'),
#   Text(1.0369047612548579, 0.6040103609103128, 'Denied')],
#  [Text(-0.7776785709411433, -0.45300777068273457, '66.79%'),
#   Text(0.6048611107320004, 0.3523393771976824, '33.21%')])

# %%
plt.pie(x=values,labels=labels,
       autopct=("%1.2f%%"),
        wedgeprops={"edgecolor":"red"}, # dict 
       shadow=True,
       explode=[0.3,0.1],
       startangle=220)
# Out:
# ([<matplotlib.patches.Wedge at 0x25cdc208760>,
# ...
#  [Text(1.317409699108108, -0.4737422133353589, 'Certified'),
#   Text(-1.1292083135212356, 0.4060647542874496, 'Denied')],
#  [Text(0.8469062351409266, -0.3045485657155878, '66.79%'),
#   Text(-0.6587048495540542, 0.2368711066676789, '33.21%')])
