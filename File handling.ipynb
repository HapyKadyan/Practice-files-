# %% [markdown]
# - .txt files
#
# - josn files
#
# - csv files (comma seperated value) (Pandas)
#
# - .xlsx files (Pandas)

# %% [markdown]
# **Read and write**

# %%
# Step-1: 
# Reading a text file
# I shared some files in whatsup
# Downlaod and save in one location

# %%
# any file to open
# First you need to understand the location
# Tell me how do you know at which locatio your file has opened using python?

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\python_sessions'

# %%
# There are two ways to open
# Your file location:'C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda'
# Python book location: 'C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\python_sessions'
# There are two ways to open

# %%
# Case-1:
# Observation-1: Your file and notebook is on different location
# Provide filename with extension of type of file
# file=open('C:\Users\omkar\OneDrive\Documents\Data science\Ekeeda')
# When you provide file location make sure change single slash to double slash
# You can open with single slash also that is different case

# <File location>\\<filename>.<extension>

file=open('C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\mbox-short.txt')

# %%
file
# Out:
# <_io.TextIOWrapper name='C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\mbox-short.txt' mode='r' encoding='cp1252'>

# %%
dir(file)
# Out:
# ['_CHUNK_SIZE',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
file=open('C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\mbox-short.txt')
file.read()
# Out:
# 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\nReturn-Path: <postmaster@collab.sakaiproject.org>\nReceived: from murder (mail.umich.edu [141.211.14.90])\n\t by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;\n\t Sat, 05 Jan 2008 09:14:16 -0500\nX-Sieve: CMU Sieve 2.3\nReceived: from murder ([unix socket])\n\t by mail.umich.edu (Cyrus v2.2.12) with LMTPA;\n\t Sat, 05 Jan 2008 09:14:16 -0500\nReceived: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])\n\tby flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;\n\tSat, 5 Jan 2008 09:14:15 -0500\nReceived: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])\n\tBY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ; \n\t 5 Jan 2008 09:14:10 -0500\nReceived: from paploo.uhi.ac.uk (localhost [127.0.0.1])\n\tby paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;\n\tSat,  5 Jan 2008 14:10:05 +0000 (GMT)\nMessage-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>\nMime-Version: 1.0\n
# ...

# %%
mystr="A\nB"
print(mystr)
# Out:
# A
# B

# %%
file=open('C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\mbox-short.txt')
print(file.read())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %% [markdown]
# *with*

# %%
file_path='C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\mbox-short.txt'
with open(file_path,'r') as file:
    print(file.read())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
file=open('C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\mbox-short.txt')
file.read()[0]
#print(len(file.read()))
#file.read()[0]
# Out:
# 'F'

# %%
# 94626
# Index last
# Words
# Words with spaces
# letters

# %%
file_path='C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\mbox-short.txt'
with open(file_path,'r') as file:
    file_name=file.read()
    print(file_name[0:13])

print(len(file_name))
# Out:
# From stephen.
# 94626

# %%
# In this file you have 94626 charcters are there
# Charcters includes letters,symobls and spaces
print(file_name)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
file=open('C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\mbox-short.txt')
for i in file:  # reading lines directly from path  not using any read method
    print(i)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# Return-Path: <postmaster@collab.sakaiproject.org>
#
# Received: from murder (mail.umich.edu [141.211.14.90])
#
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# X-Sieve: CMU Sieve 2.3
#
# Received: from murder ([unix socket])
#
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# 	Sat, 5 Jan 2008 09:14:15 -0500
#
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
#
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
#
# 	 5 Jan 2008 09:14:10 -0500
#
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
#
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
#
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
#
# ...

# %%
with open(file_path,'r') as file:
    for i in file:
        print(i)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# Return-Path: <postmaster@collab.sakaiproject.org>
#
# Received: from murder (mail.umich.edu [141.211.14.90])
#
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# X-Sieve: CMU Sieve 2.3
#
# Received: from murder ([unix socket])
#
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# 	Sat, 5 Jan 2008 09:14:15 -0500
#
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
#
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
#
# 	 5 Jan 2008 09:14:10 -0500
#
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
#
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
#
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
#
# ...

# %%
# Without for loop

# Step-1:
file=open('C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\mbox-short.txt')
print(file.read())

# Step-2:
file_path='C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\mbox-short.txt'
with open(file_path,'r') as file:
    file_name=file.read()

print(len(file_name))


#===============With for loop==========================================
# Step-1:

file=open('C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\mbox-short.txt')
for i in open(file_path):  # reading lines directly from path  not using any read method
    print(i)
    
for i in file:
    print(i)
    
# Step-2:
with open(file_path,'r') as file:
    for i in file:
        print(i)

# %% [markdown]
# $Enumerate$

# %%
# One file is automonile details
# Second file is its address
with open(file_path,'r') as file:
    for i,j in enumerate(file):
        print(i,j)
        
# i = index of the sentence
# j = sentence
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
#
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
#
# 3 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 4 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 5 X-Sieve: CMU Sieve 2.3
#
# 6 Received: from murder ([unix socket])
#
# 7 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 8 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# 11 	Sat, 5 Jan 2008 09:14:15 -0500
#
# 12 Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
#
# 13 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
#
# 14 	 5 Jan 2008 09:14:10 -0500
#
# 15 Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
#
# 16 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
#
# 17 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
#
# ...

# %%
# Print first 10 lines 
# m-1
with open(file_path,'r') as file:
    for i,j in enumerate(file):
        if i<11:
            print(i,j)
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
#
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
#
# 3 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 4 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 5 X-Sieve: CMU Sieve 2.3
#
# 6 Received: from murder ([unix socket])
#
# 7 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 8 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;

# %%
#m-2
with open(file_path,'r') as file:
    for i,j in enumerate(file):
        if i<11:
            print(i,j)
        else:
            break
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
#
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
#
# 3 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 4 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 5 X-Sieve: CMU Sieve 2.3
#
# 6 Received: from murder ([unix socket])
#
# 7 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 8 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;

# %%
#m-3
with open(file_path,'r') as file:
    for i,j in enumerate(file):
        print(i,j)
        if i==10:
            break
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
#
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
#
# 3 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 4 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 5 X-Sieve: CMU Sieve 2.3
#
# 6 Received: from murder ([unix socket])
#
# 7 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 8 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;

# %%
#q-2: print first 20 lines
# make sure all the lines in same alignment

# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008

# 1 Return-Path: <postmaster@collab.sakaiproject.org>

# 2 Received: from murder (mail.umich.edu [141.211.14.90])

# 3 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;

# 4 Sat, 05 Jan 2008 09:14:16 -0500

# %%
with open(file_path,"r") as file:
    for i,j in enumerate(file):
        if i<=10:
            print(i,j.lstrip())
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
#
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
#
# 3 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 4 Sat, 05 Jan 2008 09:14:16 -0500
#
# 5 X-Sieve: CMU Sieve 2.3
#
# 6 Received: from murder ([unix socket])
#
# 7 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 8 Sat, 05 Jan 2008 09:14:16 -0500
#
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10 by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;

# %%
#q-3:
# I want the lines those are starting 'From' keyword
# count of that lines
with open(file_path,"r") as file:
    for i,j in enumerate(file):
        j=j.lstrip()
        if i<=100:
            if j[0:4] in "From":
                print(i,j)
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 37 From: stephen.marquard@uct.ac.za
#
# 46
# 48
# 52
# 58
# 62
# 63
# 64
# 65 From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008

# %%
list_from=[]
with open(file_path,"r") as file:
    for i,j in enumerate(file):
        if j.startswith("From"):
            list_from.append(j)

# %%
list_from_2=[]
for line in open(file_path):
    if line.startswith("From"):
        list_from_2.append(line)

# %%
list_from_1=[line for line in open(file_path) if line.startswith("From")]

# %%
list_from_1
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\n',
#  'From: stephen.marquard@uct.ac.za\n',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008\n',
#  'From: louis@media.berkeley.edu\n',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008\n',
#  'From: zqian@umich.edu\n',
# ...

# %%
#q-4: get all the email ids from above list_from_1
# and make one more list wih email ids
# Do split in every line
# If pattern is same
# Retrive emails using index

email_id=[i.split(' ')[1].rstrip('\n') for i in list_from]
len(email_id)
# Out:
# 54

# %%
# Remove the duplicates by using set operations
# Set opertaion will return elements in curly braces
# Apply list casting on set operation, we can convert into list
unique_email_id=list(set(email_id))

# %%
unique_email_id
# Out:
# ['wagnermr@iupui.edu',
#  'antranig@caret.cam.ac.uk',
#  'stephen.marquard@uct.ac.za',
#  'cwen@iupui.edu',
#  'ray@media.berkeley.edu',
#  'louis@media.berkeley.edu',
#  'gsilver@umich.edu',
#  'david.horwitz@uct.ac.za',
#  'gopal.ramasammycook@gmail.com',
#  'zqian@umich.edu',
#  'rjlowe@iupui.edu']

# %%
# emails .txt
# Read the email.txt
# 3 lists
# one is employee names
# Employee email ids
# Employee comapny name

# %%
# Open the file
# Second-case
# If both python file and your text file in same location
# No need to give entire path

# %%
file_path='emails.txt'  # no need to provide entire location
with open(file_path,'r') as file:
    file_name=file.read()

print(len(file_name))
# Out:
# 2321

# %%
file_name
# split by semicolon
# split by lessthan
# Out:
# 'Santhanam, Jayendhran <jayendhran.ms@accenture.com>; Bhattacharjee, Sankalan <s.t.bhattacharjee@accenture.com>; Bansal, Vaishnavi <vaishnavi.a.bansal@accenture.com>; Chandra Shekhar, Pavuluri <p.a.chandra.shekhar@accenture.com>; J Doshi, Hiren <hiren.j.doshi@accenture.com>; Shimoga Prakash, Jeevan <j.shimoga.prakash@accenture.com>; Akhouri, Shreyash <shreyash.akhouri@accenture.com>; Nath, Nupanga <nupanga.nath@accenture.com>; Ponna, Ramesh <r.ponna@accenture.com>; Singhal, Aditya <aditya.d.singhal@accenture.com>; Gorai, Sumit <sumit.gorai@accenture.com>; Valdez, Mariele Dyan Francely <mariele.dyan.valdez@accenture.com>; Cancel, Abigail Kyle <abigail.kyle.cancel@accenture.com>; BONDALAKUNTA, POOJITHA <p.bondalakunta@accenture.com>; priyanka uppala, sai <sai.priyanka.uppala@accenture.com>; Nitin SHINDE, NIKHIL <nikhil.nitin.shinde@accenture.com>; Chidre, Swapna <swapna.chidre@accenture.com>; Sahu, Swastik <s.satyapragyan.sahu@accenture.com>; Sikka, Ankit <ankit.sikka@accenture.com>; D
# ...

# %%
# step-1
file_path='emails.txt'  # no need to provide entire location
with open(file_path,'r') as file:
    for i in file:
        emplyee_details=i.split(';')

# %%
# Step-2: removing spaces both left and right
emplyee_details_stri=[i.strip() for i in emplyee_details]

# %%
# Step-3:
str1='Santhanam, Jayendhran <jayendhran.ms@accenture.com>'
print("Name:",str1.split('<')[0])
print("Email_id:",str1.split('<')[1])
# Out:
# Name: Santhanam, Jayendhran
# Email_id: jayendhran.ms@accenture.com>

# %%
#step-4
names=[i.split('<')[0].strip() for i in emplyee_details_stri]
emails=[i.split('<')[1].strip('>') for i in emplyee_details_stri]

# %%
names=[i.split('<')[0] for i in emplyee_details_stri]
# modify this line for removing spaces
# Out:
# ['Santhanam, Jayendhran ',
#  'Bhattacharjee, Sankalan ',
#  'Bansal, Vaishnavi ',
#  'Chandra Shekhar, Pavuluri ',
#  'J Doshi, Hiren ',
#  'Shimoga Prakash, Jeevan ',
#  'Akhouri, Shreyash ',
#  'Nath, Nupanga ',
#  'Ponna, Ramesh ',
#  'Singhal, Aditya ',
#  'Gorai, Sumit ',
#  'Valdez, Mariele Dyan Francely ',
#  'Cancel, Abigail Kyle ',
#  'BONDALAKUNTA, POOJITHA ',
#  'priyanka uppala, sai ',
#  'Nitin SHINDE, NIKHIL ',
#  'Chidre, Swapna ',
#  'Sahu, Swastik ',
#  'Sikka, Ankit ',
#  'Dara, Sai Madhukar ',
#  'Pattanshetti, Sampreet ',
#  'Sharma, Ayush ',
#  'Latorena, Zairous Jay ',
#  'Abhimanyu Pradhan, Roshankumar ',
#  'Jaiswal, Lehar ',
#  'Gupta, Retik ',
#  'Satti, Phanindra Reddy ',
#  'Kumar, Manish ',
#  'Balakrishnan, Devi Priya ',
#  'M S, Roshni Priya ',
#  'Cheerala, Vanaja ',
#  'G D, Chandrashekhar ',
#  'Nikhil Reddy, Madithati ',
#  'Santos, Jeroshelle V. ',
#  'Milan, Gerald John ',
#  'Gupta, Vivek ',
#  'Mandal, Sumit ',
#  'Prakash Shukla, Ashok ',
# ...

# %% [markdown]
# **Write a text file**

# %%
# write some thing
with open('readme.txt','w') as f:
    f.write('today is sunday')

# %%
# reading the same file
with open('readme.txt','r') as f:
    print(f.read())
# Out:
# today is sunday

# %% [markdown]
# **Read and write json file**

# %%
# if you want save a dictionary
# choose json format

# %%
dict1={'name':'Anil',
      'School':'DPS',
      'Marks':90}

# %%
with open('dict1.txt','w') as f:
    f.write(dict1)

# if the value is not in string type
# you cant save in text file
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-d73140cb6108> in <module>
#       1 with open('dict1.txt','w') as f:
# ----> 2     f.write(dict1)
#
# TypeError: write() argument must be str, not dict

# %%
# Step-1: import json package
import json

# %%
# Step-2:
# need to be create a json object, by dumping the information
# in json package
# This is called Serialization
dict1={'name':'Anil',
      'School':'DPS',
      'Marks':90}
obj=json.dumps(dict1)
obj
# Out:
# '{"name": "Anil", "School": "DPS", "Marks": 90}'

# %%
# step-3:
with open('sample.json','w') as f:
    f.write(obj)

# %%
# Reading json
with open('sample.json','r') as f:
    print(json.load(f))
# Out:
# {'name': 'Anil', 'School': 'DPS', 'Marks': 90}
