# %%
# importing necessary libaries 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("D:\\data\\car_price.csv")
df.head()
# Out:
#    Unnamed: 0                                car_name car_prices_in_rupee  \
# 0           0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1           1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2           2                      Toyota Camry 2.5 G          16.40 Lakh
# 3           3                       Honda Jazz VX CVT           7.77 Lakh
# 4           4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
#
#    kms_driven fuel_type transmission  ownership  manufacture   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1  13,248 kms    Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats
# 2  60,343 kms    Petrol    Automatic  1st Owner         2016  2494 cc  5 Seats
# 3  26,696 kms    Petrol    Automatic  1st Owner         2018  1199 cc  5 Seats
# 4  69,414 kms    Petrol       Manual  1st Owner         2016  1199 cc  5 Seats

# %%
df.shape
# Out:
# (5512, 10)

# %%
df.info()
# there is no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           5512 non-null   int64
#  1   car_name             5512 non-null   object
#  2   car_prices_in_rupee  5512 non-null   object
#  3   kms_driven           5512 non-null   object
#  4   fuel_type            5512 non-null   object
#  5   transmission         5512 non-null   object
#  6   ownership            5512 non-null   object
#  7   manufacture          5512 non-null   int64
#  8   engine               5512 non-null   object
#  9   Seats                5512 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 430.8+ KB

# %%
df.duplicated().sum()
# no duplicate values
# Out:
# 0

# %%
# droping unnecasssery column 
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                  car_name car_prices_in_rupee  kms_driven  \
# 0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh  86,226 kms
# 1            Renault Duster RXZ Turbo CVT          12.83 Lakh  13,248 kms
# 2                      Toyota Camry 2.5 G          16.40 Lakh  60,343 kms
# 3                       Honda Jazz VX CVT           7.77 Lakh  26,696 kms
# 4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh  69,414 kms
#
#   fuel_type transmission  ownership  manufacture   engine    Seats
# 0    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1    Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats
# 2    Petrol    Automatic  1st Owner         2016  2494 cc  5 Seats
# 3    Petrol    Automatic  1st Owner         2018  1199 cc  5 Seats
# 4    Petrol       Manual  1st Owner         2016  1199 cc  5 Seats

# %%
df.describe(include="all")
# Out:
#                    car_name car_prices_in_rupee  kms_driven fuel_type  \
# count                  5512                5512        5512      5512
# unique                 1896                1300        2610         5
# top     Maruti Alto 800 LXI           4.50 Lakh  80,000 kms    Petrol
# freq                     53                  62         163      2967
# mean                    NaN                 NaN         NaN       NaN
# std                     NaN                 NaN         NaN       NaN
# min                     NaN                 NaN         NaN       NaN
# 25%                     NaN                 NaN         NaN       NaN
# 50%                     NaN                 NaN         NaN       NaN
# 75%                     NaN                 NaN         NaN       NaN
# max                     NaN                 NaN         NaN       NaN
#
#        transmission  ownership  manufacture   engine    Seats
# count          5512       5512  5512.000000     5512     5512
# ...

# %%
# here car_price , kms_driven, manufacture ,engine seats are in string 
# we need to convert them into int 
# how to convert string to int ??
df.rename(columns={"car_prices_in_rupee":"car_price"},inplace=True)
# name is too large

# %%
df.head()
# Out:
#                                  car_name   car_price  kms_driven fuel_type  \
# 0  Jeep Compass 2.0 Longitude Option BSIV  10.03 Lakh  86,226 kms    Diesel
# 1            Renault Duster RXZ Turbo CVT  12.83 Lakh  13,248 kms    Petrol
# 2                      Toyota Camry 2.5 G  16.40 Lakh  60,343 kms    Petrol
# 3                       Honda Jazz VX CVT   7.77 Lakh  26,696 kms    Petrol
# 4        Volkswagen Polo 1.2 MPI Highline   5.15 Lakh  69,414 kms    Petrol
#
#   transmission  ownership  manufacture   engine    Seats
# 0       Manual  1st Owner         2017  1956 cc  5 Seats
# 1    Automatic  1st Owner         2021  1330 cc  5 Seats
# 2    Automatic  1st Owner         2016  2494 cc  5 Seats
# 3    Automatic  1st Owner         2018  1199 cc  5 Seats
# 4       Manual  1st Owner         2016  1199 cc  5 Seats

# %%
# now convert car_price into int 
df["car_price"]=df["car_price"].astype(float)
# here 10.03 lakh is not converted into float 
# we have to remove lakh from the column
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 2>()
#       1 # now convert car_price into int
# ----> 2 df["car_price"]=df["car_price"].astype(float,error="raise")
#
# TypeError: astype() got an unexpected keyword argument 'error'

# %%
car_list_price=df["car_price"].tolist()
car_list_price
# Out:
# ['10.03 Lakh',
#  '12.83 Lakh',
#  '16.40 Lakh',
#  '7.77 Lakh',
#  '5.15 Lakh',
#  '7.66 Lakh',
#  '7.58 Lakh',
#  '11.60 Lakh',
#  '6.99 Lakh',
#  '7.53 Lakh',
#  '6.43 Lakh',
#  '5.43 Lakh',
#  '8.62 Lakh',
#  '16.78 Lakh',
#  '10.03 Lakh',
#  '5.63 Lakh',
#  '6.67 Lakh',
#  '6.73 Lakh',
#  '3.21 Lakh',
#  '8.50 Lakh',
#  '4.34 Lakh',
#  '3.11 Lakh',
#  '3.70 Lakh',
#  '15.88 Lakh',
#  '5.41 Lakh',
#  '2.23 Lakh',
#  '5.88 Lakh',
#  '22.78 Lakh',
#  '6.12 Lakh',
#  '7.44 Lakh',
#  '8.39 Lakh',
#  '4.20 Lakh',
#  '4.91 Lakh',
#  '2.93 Lakh',
#  '2.98 Lakh',
#  '2.60 Lakh',
#  '2.38 Lakh',
#  '6.05 Lakh',
#  '3.23 Lakh',
#  '3.26 Lakh',
#  '4.21 Lakh',
#  '15.53 Lakh',
#  '12.43 Lakh',
#  '18.50 Lakh',
#  '15.90 Lakh',
#  '8.90 Lakh',
#  '43 Lakh',
#  '6 Lakh',
#  '27 Lakh',
#  '10.90 Lakh',
#  '5.90 Lakh',
#  '6.50 Lakh',
#  '6.75 Lakh',
#  '3.70 Lakh',
#  '5.25 Lakh',
#  '7.25 Lakh',
#  '8.50 Lakh',
#  '14 Lakh',
#  '15 Lakh',
#  '13.90 Lakh',
#  '8.90 Lakh',
#  '16.90 Lakh',
# ...

# %%
for i in car_list_price:
    a=i.rstrip(" Lakh")
    df["car_price"]=df["car_price"].replace(i,a)
print(df['car_price'])
# i is old value
# a is new value 
# replace(old value,new value )
# Out:
# 0       10.03
# 1       12.83
# 2       16.40
# 3        7.77
# 4        5.15
#         ...
# 5507    28.90
# 5508    64.90
# 5509    13.75
# 5510    29.90
# 5511    31.90
# Name: car_price, Length: 5512, dtype: object

# %%
df.head()
# Out:
#                                  car_name car_price  kms_driven fuel_type  \
# 0  Jeep Compass 2.0 Longitude Option BSIV     10.03  86,226 kms    Diesel
# 1            Renault Duster RXZ Turbo CVT     12.83  13,248 kms    Petrol
# 2                      Toyota Camry 2.5 G     16.40  60,343 kms    Petrol
# 3                       Honda Jazz VX CVT      7.77  26,696 kms    Petrol
# 4        Volkswagen Polo 1.2 MPI Highline      5.15  69,414 kms    Petrol
#
#   transmission  ownership  manufacture   engine    Seats
# 0       Manual  1st Owner         2017  1956 cc  5 Seats
# 1    Automatic  1st Owner         2021  1330 cc  5 Seats
# 2    Automatic  1st Owner         2016  2494 cc  5 Seats
# 3    Automatic  1st Owner         2018  1199 cc  5 Seats
# 4       Manual  1st Owner         2016  1199 cc  5 Seats

# %%
# now remove kms from kms_driven 
for i in list(df["kms_driven"]):
    b=i.rstrip(" kms")
    df["kms_driven"]=df["kms_driven"].replace(i,b)

# %%
# now for engine 
for i in list(df["engine"]):
    c=i.strip(" cc")
    df["engine"]=df["engine"].replace(i,c)

# %%
# now for seats 
for i in list(df["Seats"]):
    d=i.strip("Seats")
    df["Seats"]=df["Seats"].replace(i,d)

# %%
df.head()
# now clear
# Out:
#                                  car_name car_price kms_driven fuel_type  \
# 0  Jeep Compass 2.0 Longitude Option BSIV     10.03     86,226    Diesel
# 1            Renault Duster RXZ Turbo CVT     12.83     13,248    Petrol
# 2                      Toyota Camry 2.5 G     16.40     60,343    Petrol
# 3                       Honda Jazz VX CVT      7.77     26,696    Petrol
# 4        Volkswagen Polo 1.2 MPI Highline      5.15     69,414    Petrol
#
#   transmission  ownership  manufacture engine Seats
# 0       Manual  1st Owner         2017   1956    5
# 1    Automatic  1st Owner         2021   1330    5
# 2    Automatic  1st Owner         2016   2494    5
# 3    Automatic  1st Owner         2018   1199    5
# 4       Manual  1st Owner         2016   1199    5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car_name      5512 non-null   object
#  1   car_price     5512 non-null   object
#  2   kms_driven    5512 non-null   object
#  3   fuel_type     5512 non-null   object
#  4   transmission  5512 non-null   object
#  5   ownership     5512 non-null   object
#  6   manufacture   5512 non-null   int64
#  7   engine        5512 non-null   object
#  8   Seats         5512 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 387.7+ KB

# %%
# now convert some columns into numerical values 
df["car_price"]=df["car_price"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [89], in <cell line: 2>()
#       1 # now convert some columns into numerical values
# ----> 2 df["car_price"]=df["car_price"].astype(float)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
def num1(i):
    for i in list(df["car_price"]):
        if "," in i:
            a=df["car_price"].replace(",","")
            return a
        else:
            return i 
df["car_price"]=df["car_price"].

# %%
def handle(value):
    if value==",":
        value=value.split(",")
        value=value[0]+value[1]
        return float(value)
    else: 
        return float(value)
df["car_price"]=df["car_price"].apply(handle)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [159], in <cell line: 8>()
#       6     else:
#       7         return float(value)
# ----> 8 df["car_price"]=df["car_price"].apply(handle)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
# ...

# %%
df["car_price"]=df["car_price"].astype(float)

# %%
# remove , from the car_price values 
df["car_price"].max()
# Out:
# '10.03'

# %%
df["car_price"].nunique()
# Out:
# 1

# %%
df["car_price"].value_counts()
# Out:
# 10.03    5512
# Name: car_price, dtype: int64

# %%
df["kms_driven"].nunique()
# Out:
# 2610

# %%
df["kms_driven"].value_counts()
# Out:
# 80,000      163
# 1,20,000    146
# 60,000      142
# 50,000      136
# 70,000      132
#            ...
# 79,385        1
# 51,242        1
# 38,733        1
# 77,385        1
# 85,002        1
# Name: kms_driven, Length: 2610, dtype: int64

# %%
# convert kms_driven into numerical 
df["kms_driven"]=df["kms_driven"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [114], in <cell line: 2>()
#       1 # convert kms_driven into numerical
# ----> 2 df["kms_driven"]=df["kms_driven"].astype(float)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
# now engine 
df["engine"]=df["engine"].astype(int)

# %%
# now seats 
df["Seats"]=df["Seats"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car_name      5512 non-null   object
#  1   car_price     5512 non-null   float64
#  2   kms_driven    5512 non-null   object
#  3   fuel_type     5512 non-null   object
#  4   transmission  5512 non-null   object
#  5   ownership     5512 non-null   object
#  6   manufacture   5512 non-null   int64
#  7   engine        5512 non-null   int32
#  8   Seats         5512 non-null   int32
# dtypes: float64(1), int32(2), int64(1), object(5)
# memory usage: 344.6+ KB

# %%
a="12,3"
a.replace(",","")
# Out:
# '123'

# %%
# Out:
#           car_price  manufacture       engine        Seats
# count  5.512000e+03  5512.000000  5512.000000  5512.000000
# mean   1.003000e+01  2015.455552  1532.299710     5.250726
# std    7.337019e-13     3.927974   579.210876     0.720075
# min    1.003000e+01  1995.000000     0.000000     2.000000
# 25%    1.003000e+01  2013.000000  1197.000000     5.000000
# 50%    1.003000e+01  2016.000000  1396.000000     5.000000
# 75%    1.003000e+01  2018.000000  1950.000000     5.000000
# max    1.003000e+01  2022.000000  5950.000000     8.000000

# %%
# no need to convert object to int or float

# %%
df=pd.read_csv("D:\\data\\car_price.csv")
df.head()
# Out:
#    Unnamed: 0                                car_name car_prices_in_rupee  \
# 0           0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1           1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2           2                      Toyota Camry 2.5 G          16.40 Lakh
# 3           3                       Honda Jazz VX CVT           7.77 Lakh
# 4           4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
#
#    kms_driven fuel_type transmission  ownership  manufacture   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1  13,248 kms    Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats
# 2  60,343 kms    Petrol    Automatic  1st Owner         2016  2494 cc  5 Seats
# 3  26,696 kms    Petrol    Automatic  1st Owner         2018  1199 cc  5 Seats
# 4  69,414 kms    Petrol       Manual  1st Owner         2016  1199 cc  5 Seats

# %%
# droping unnecasssery column 
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df["car_name"].nunique()
# Out:
# 1896

# %%
sns.countplot(df["car_name"])
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='car_name', ylabel='count'>

# %%
sns.countplot(df["transmission"])
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='transmission', ylabel='count'>

# %%
sns.countplot(df["fuel_type"])
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fuel_type', ylabel='count'>

# %%
sns.countplot(df["Seats"])
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Seats', ylabel='count'>

# %%
sns.countplot(df["ownership"])
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ownership', ylabel='count'>

# %%
sns.countplot(df["manufacture"],hue=df["transmission"])
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='manufacture', ylabel='count'>

# %%
sns.countplot(df["fuel_type"],hue=df["transmission"])
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fuel_type', ylabel='count'>

# %%
sns.countplot(df["engine"],hue=df["Seats"])
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='engine', ylabel='count'>
